# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("crop.csv")
df.head()
# Out:
#                          State  District  Year       Season  \
# 0  Andaman and Nicobar Islands  NICOBARS  2000  Kharif
# 1  Andaman and Nicobar Islands  NICOBARS  2000  Kharif
# 2  Andaman and Nicobar Islands  NICOBARS  2000  Kharif
# 3  Andaman and Nicobar Islands  NICOBARS  2000  Whole Year
# 4  Andaman and Nicobar Islands  NICOBARS  2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
df.dropna(subset=["Production"],axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# State         0
# District      0
# Year          0
# Season        0
# Crop          0
# Area          0
# Production    0
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#                               State  District  Year       Season  \
# 0       Andaman and Nicobar Islands  NICOBARS  2000  Kharif
# 1       Andaman and Nicobar Islands  NICOBARS  2000  Kharif
# 2       Andaman and Nicobar Islands  NICOBARS  2000  Kharif
# 3       Andaman and Nicobar Islands  NICOBARS  2000  Whole Year
# 4       Andaman and Nicobar Islands  NICOBARS  2000  Whole Year
# ...                             ...       ...   ...          ...
# 246086                  West Bengal   PURULIA  2014  Summer
# 246087                  West Bengal   PURULIA  2014  Summer
# 246088                  West Bengal   PURULIA  2014  Whole Year
# 246089                  West Bengal   PURULIA  2014  Winter
# 246090                  West Bengal   PURULIA  2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# ...

# %%
df.isnull().sum()
# Out:
# State         0
# District      0
# Year          0
# Season        0
# Crop          0
# Area          0
# Production    0
# dtype: int64

# %%
newdf=df.loc[((df['State']=="Andaman and Nicobar Islands") & (df['Crop']=='Arecanut') )]
newdf
# Out:
#                            State                  District  Year       Season  \
# 0    Andaman and Nicobar Islands                  NICOBARS  2000  Kharif
# 10   Andaman and Nicobar Islands                  NICOBARS  2001  Kharif
# 19   Andaman and Nicobar Islands                  NICOBARS  2002  Whole Year
# 28   Andaman and Nicobar Islands                  NICOBARS  2003  Whole Year
# 37   Andaman and Nicobar Islands                  NICOBARS  2004  Whole Year
# 53   Andaman and Nicobar Islands                  NICOBARS  2006  Whole Year
# 66   Andaman and Nicobar Islands                  NICOBARS  2010  Rabi
# 79   Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  2000  Kharif
# 90   Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  2001  Kharif
# 99   Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  2006  Whole Year
# 113  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  2010  Rabi
# ...

# %%
from sklearn import preprocessing, svm 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
X = np.array(newdf['Area']).reshape(-1, 1) 
y = np.array(newdf['Production']).reshape(-1, 1)

# %%
newdf.isnull().sum()
# Out:
# State         0
# District      0
# Year          0
# Season        0
# Crop          0
# Area          0
# Production    0
# dtype: int64

# %%
newdf.dropna()
# Out:
#                            State                  District  Year       Season  \
# 0    Andaman and Nicobar Islands                  NICOBARS  2000  Kharif
# 10   Andaman and Nicobar Islands                  NICOBARS  2001  Kharif
# 19   Andaman and Nicobar Islands                  NICOBARS  2002  Whole Year
# 28   Andaman and Nicobar Islands                  NICOBARS  2003  Whole Year
# 37   Andaman and Nicobar Islands                  NICOBARS  2004  Whole Year
# 53   Andaman and Nicobar Islands                  NICOBARS  2006  Whole Year
# 66   Andaman and Nicobar Islands                  NICOBARS  2010  Rabi
# 79   Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  2000  Kharif
# 90   Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  2001  Kharif
# 99   Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  2006  Whole Year
# 113  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  2010  Rabi
# ...

# %%
newdf.isnull().sum()
newdf.dropna()
newdf.isnull().sum()
# Out:
# State         0
# District      0
# Year          0
# Season        0
# Crop          0
# Area          0
# Production    0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

print(y_train)
regr = LinearRegression()
regr.fit(X_train, y_train) 
print(regr.score(X_test, y_test))

result=regr.predict([[502]])
round(result[0][0])
# Out:
# [[ 805.85]
#  [5182.  ]
#  [3058.46]
#  [2290.  ]
#  [1900.  ]
#  [1610.  ]
#  [2061.  ]
#  [3975.2 ]
#  [1525.  ]
#  [5239.  ]
#  [5200.  ]
#  [3011.7 ]]
# 0.832471200153996
# 899.0

# %%
w0=regr.coef_[0]   # this will hold the value of the slope 
w1=regr.intercept_

# %%
def predict(mi):
    exp=mi      #yahan apan ne min ka data diya 
    res=w1*exp+w0
    print("Expected max:: ",round(res[0],2))

#     exp=ma # yahan par apan ne max ka data diya
#     res2=(exp-w0)/w1
#     print("Expected min:: ",round(res2[0],2))
    
predict(502)
# Out:
# Expected max::  115077.03

# %%
result=regr.predict([[502]])
round(result[0][0])
# Out:
# 147.0

# %%
p1=newdf["Area"].mean()
p2=newdf["Production"].mean()

los=p2/p1
print(los,"ton/hec")
print(520*los)
# Out:
# 1.4410389945446334 ton/hec
# 749.3402771632093

# %%
df.isnull().sum()
# Out:
# State         0
# District      0
# Year          0
# Season        0
# Crop          0
# Area          0
# Production    0
# dtype: int64
